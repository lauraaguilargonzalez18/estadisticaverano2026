# %% [markdown]
# <a href="https://colab.research.google.com/github/lauraaguilargonzalez18/estadisticaverano2026/blob/main/studentperformance/Problemario_Estad%C3%ADstica_Inferencial_II_lauraag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
"promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
df
# Out:
#     promedio_de_examenes_cortos  promedio_final
# 0                            59              64
# 1                            92              84
# 2                            72              77
# 3                            90              80
# 4                            95              77
# 5                            87              81
# 6                            89              80
# 7                            77              84
# 8                            76              80
# 9                            65              69
# 10                           97              83
# 11                           42              40
# 12                           94              78
# 13                           62              65
# 14                           91              90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   promedio_de_examenes_cortos  15 non-null     int64
#  1   promedio_final               15 non-null     int64
# dtypes: int64(2)
# memory usage: 372.0 bytes

# %%
df.describe()
# Out:
#        promedio_de_examenes_cortos  promedio_final
# count                    15.000000       15.000000
# mean                     79.200000       75.466667
# std                      16.297239       12.123570
# min                      42.000000       40.000000
# 25%                      68.500000       73.000000
# 50%                      87.000000       80.000000
# 75%                      91.500000       82.000000
# max                      97.000000       90.000000

# %%
#1.Establece una variable dependiente(y) y una variable independiente (x)
y=df["promedio_final"]
x=df["promedio_de_examenes_cortos"]

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
# --- Configuración general del gráfico --
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)
# --- Gráfico de dispersión --
plt.scatter(
    x, y,
    marker="*",       # forma
    color='dodgerblue',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=50,                 # tamaño de los puntos
    label='Promedio_de_examenes_cortos' # etiqueta para la leyenda
)
# --- Gráfico de línea --
# plt.plot(
#     x, y,
#     color='orange',   # color de la línea
#     linewidth=2.2,        # grosor de la línea
#     linestyle='-',        # estilo de línea
#     marker='o',           # marcador en cada punto
#     markersize=5,         # tamaño del marcador
#     markerfacecolor='white',
#     markeredgecolor='black',
#     label='Datos observados'
# )
# --- Título --
plt.title(
    'Gráfico de dispersión entre promedio deexamenes cortos y promedio final ',
    fontsize=14,
    fontweight='bold'
)
# --- Etiquetas de los ejes --
plt.xlabel(
    'Promedio de examenes cortos',
    fontsize=12
)
plt.ylabel(
    'Promedio final',
    fontsize=12
)
# --- Fuente de los ticks --
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# --- Márgenes --
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
# Para eliminar márgenes completamente, usar:
# plt.margins(0)
# --- Cuadrícula (opcional, pero didáctica) --
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.9,
    alpha=0.3,
    color="black"
)
# --- Leyenda --
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)
# --- Nota al pie --
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)
# --- Guardar gráfico --
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )
plt.show()

# %%
#4 calcula el coeficiente de correcion e interpreta el resultado
from scipy.stats import pearsonr
r, valor_p= pearsonr(x,y)#p prueba de hipotesis
#corelacion: el cambio en una variable esta vinculado con el cambio en otra variable
print(f"Coeficiente de correlacion(r):{r:0.4f}")
print(f"valor-p:{valor_p:0.4f}")
#Ho:si hay correlacion
# Out:
# Coeficiente de correlacion(r):0.8646
# valor-p:0.0000

# %%
#5 calcule el coeficiente de determinacion
print(f"Coeficiente de determinacion:{r**2:0.4f}")#dos asterisco elebando la potencia
#un asterisco es multiplicacion
# Out:
# Coeficiente de determinacion:0.7475

# %%
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el
# gráfico de dispersión
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)
modelo.params
# Out:
# const                          24.526822
# promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
# --- Configuración general del gráfico --
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)
# --- Gráfico de dispersión --
plt.scatter(
    x, y,
    marker="s",       # forma
    color='dodgerblue',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='Promedio_de_examenes_cortos' # etiqueta para la leyenda
)
# --- Gráfico de línea --
plt.plot(
    x, y_calculada,
    color='red',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)
# --- Título --
plt.title(
    'Gráfico de dispersión entre Promedio de examene cortos ypromedio final',
    fontsize=14,
    fontweight='bold'
)
# --- Etiquetas de los ejes --
plt.xlabel(
'Promedio de examenes cortos',
fontsize=12
)
plt.ylabel(
'Promedio Final',
fontsize=12
)
# --- Fuente de los ticks --
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# --- Márgenes --
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)
# Para eliminar márgenes completamente, usar:
# plt.margins(0)
# superior
# --- Cuadrícula (opcional, pero didáctica) --
plt.grid(
visible=True,
linestyle='--',
linewidth=0.9,
alpha=0.3,
color="black"
)
# --- Leyenda --
plt.legend(
fontsize=10,
loc='best',
frameon=True
)
# --- Nota al pie --
plt.text(
0.4, -0.2,
'Fuente: datos simulados para fines académicos.',
fontsize=8,
ha='left',
va='center',
transform=plt.gca().transAxes
)
# --- Guardar gráfico --
plt.savefig(
"grafico de dispersión",
bbox_inches='tight'
)
plt.show()

# %%
modelo.params
# Out:
# const                          24.526822
# promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
# intervalo de confianza = 1 - alpha
modelo.conf_int(alpha = 0.05)
# Out:
#                                     0          1
# const                        6.441997  42.611646
# promedio_de_examenes_cortos  0.419219   0.867141

# %%
#8 Residuales
residuales=modelo.resid
#Gráfico de dispersión
plt.scatter(
x,residuales, #variables a graficar
marker="o",
color="dodgerblue",
edgecolor="blue", #color del borde
alpha=0.9, #transparencia
s=60, #tamaño de cada punto
label="promedio_final" #etiqueta
)
#Título
plt.title(
"gráfico de dispersión",
fontsize=12, #tamaño de fuente
fontweight="bold" #bold:negritas
)
#Etiqueta eje x
plt.xlabel(
"promedio_de_examenes_cortos",
fontsize=10
)
#Etiqueta eje y
plt.ylabel(
"promedio_final",
fontsize=10
)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
#márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)
#Malla
plt.grid(
visible=True,
linestyle="--",
linewidth=0.9, #ancho de línea
alpha=0.3, #transparencia
color="black"
)
#Leyenda
plt.legend(
fontsize=10,
loc="best",
frameon=False,
bbox_to_anchor=(0.7,-0.15)
)
#Guardar imagen
plt.savefig(
"dispersión",
bbox_inches="tight"
)
plt.axhline(y=0, color="gray",linestyle="--") #lineas horizontal

# %%
#9 Test de Shapiro
from scipy.stats import shapiro
estadistico,valor_p=shapiro(residuales)
print(f"valor_p:{valor_p:0.4f}")
# Out:
# valor_p:0.9018

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")
# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()
# Histograma
sns.histplot(residuales, kde=True)
# Out:
# valor-p (Shapiro) = 0.901827735700704
# <Axes: ylabel='Count'>

# %%
#10 Test de Breusch-Pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# si el valor es menor a sigma s rechaza H0
# Out:
# valor_p:0.2289

# %%
modelo.predict([1,70])
#x=75 y=72.77
#=84 y=78.55
# Out:
# array([69.54941193])

# %%
modelo.predict([1,75])
# Out:
# array([72.76531124])

# %%
modelo.predict([1,84])
# Out:
# array([78.55393001])

# %%
# 12. Realice una tabla ANOVA e interprete el resultado.
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('promedio_final ~promedio_de_examenes_cortos ', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                df       sum_sq      mean_sq          F  \
# promedio_de_examenes_cortos   1.0  1538.228959  1538.228959  38.492412
# Residual                     13.0   519.504375    39.961875        NaN
#
#                                PR(>F)
# promedio_de_examenes_cortos  0.000032
# Residual                          NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df= pd.DataFrame({
'salario': [11,10,8,5,9,7,3,11,8,7,2,9,8,3],
'ausencias':[18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})
df
# Out:
#     salario  ausencias
# 0        11         18
# 1        10         17
# 2         8         29
# 3         5         36
# 4         9         11
# 5         7         28
# 6         3         35
# 7        11         14
# 8         8         20
# 9         7         32
# 10        2         39
# 11        9         16
# 12        8         31
# 13        3         40

# %% [markdown]
# 2.- Realice un diagrama de dispersión para estos datos

# %%
import matplotlib.pyplot as plt
X = df["ausencias"]
Y = df["salario"]
# The lines below were incorrectly overwriting X and Y:
# Y=["salarios"]
# X=["ausencias"]
plt.scatter(
X, Y,
marker="o",
color='blue',
edgecolor='red',
alpha=0.8,
s=50,
)
plt.xlabel(
'ausencias',
            fontsize=12
)
plt.ylabel(
'salarios',
fontsize=12
)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.grid(
visible=True,
linestyle='--',
linewidth=0.7,
alpha=0.5,
color="blue"
)
plt.show()

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?
# si

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado

# %%
from scipy.stats import pearsonr
# Test de Pearson
# H0: rho = 0
# H1: rho ≠ 0
# alpha = 0.05
# (No hay correlación)
# (Sí hay correlación)
r, valor_p = pearsonr(X,Y)
print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.8801
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es
# r =−0.8801
# , este valor indica que la correlación es
# fuerte, dado que está muy cerca de 1. Además, el que sea negativa, implica que
# aumentar las ausencias ( ) disminuye el salario ( ).

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score
r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  77.46%

# %% [markdown]
# Con coeficiente de determinación de $$r^2=0.7746$$ indica que con las ausencias estoy justificando en un $77.46\%$ la variabilidad en los salarios. Por lo que el modelo puede tener una buena capacidad de predicción.

# %% [markdown]
# Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
modelo.params
# Out:
# const        14.058843
# ausencias    -0.261814
# dtype: float64

# %% [markdown]
# La ecuación de la recta es
#
# $$
# \hat y = 14.058843-0.261814X
# $$
#
# donde $x$ es el promedio en exámenes cortos

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='orange',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

plt.plot(
    X, y_calculada,
    color="pink",      # color de la línea de regresión
    alpha=0.9,         # transparencia: 0 es invisible y 1 es color sólido
    label="Recta de regresión" # Etiqueta para la leyenda
)

# Las líneas siguientes se usan típicamente en gráficos de residuales, no en la línea de regresión principal.
# Si quieres ver la línea de regresión con la etiqueta, usa plt.legend().
# plt.axhline(
#     y=0,     # Donde está la línea horizontal
#     label="Recta de regresión", # Etiqueta
#     linestyle = "--", # Estilo de línea
#     color = "black",  # color
#     linewidth=1.0   # ancho de línea
# )

# Etiquetas de los ejes
plt.xlabel(
    'ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'salarios', # etiqueta del eje y (cambiado de 'Residuales' y 'Consumo (kWh)')
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend() # Muestra la leyenda con la etiqueta de la recta de regresión
plt.show() # Muestra el gráfico

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %% [markdown]
# La recta tiene la forma:
#
# $$\hat{y}=b_0+b_1X$$

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989

# %% [markdown]
# El verdadero $b_0$ está entre $11.587445$ y $16.530241$ con una confianza del 95%. Esto indica que una persona sin ausencias ($X=0$) tiene una categoría de salario ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ está entre $-0.350638$ y $-0.172989$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre 0.172989 y 0.350638 en la categoría de salario.

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,      # <--------------------------------------------------------
    marker="*",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
#
# + Linealidad: Parece que sí, porque...
# + Normalidad: Sí cumple con la normalidad, porque...
# + Homoscedasticidad: Sí cumple con la homoscedasticidad, porque...
# + Independencia: Sí cumple, porque son diferentes personas.

# %% [markdown]
# 9. **Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.4172971767713699

# %% [markdown]
# 10. **Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.8955

# %% [markdown]
# 11. **Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict([1, 32])

print(f"Para x = 25, y =  {y_25[0]: 0.4f}")
print(f"Para x = 32, y =  {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =   7.5135
# Para x = 32, y =   5.6808

# %%
df["salario_predicho"] = y_calculada.round()
df
# Out:
#     salario  ausencias  salario_predicho
# 0        11         18               9.0
# 1        10         17              10.0
# 2         8         29               6.0
# 3         5         36               5.0
# 4         9         11              11.0
# 5         7         28               7.0
# 6         3         35               5.0
# 7        11         14              10.0
# 8         8         20               9.0
# 9         7         32               6.0
# 10        2         39               4.0
# 11        9         16              10.0
# 12        8         31               6.0
# 13        3         40               4.0

# %% [markdown]
# La extrapolación siempre debe hacerse con cuidado, aunque cumpla con todos los supuestos.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# Extrapolar, valores de x que no estén entre 11 y 40

y_10 = modelo.predict([[1, 10]])

print(f"Para x = 10, y =  {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y =   11.4407

# %% [markdown]
# Con 10 ausencias se espera que el empleado tenga una categoría de salario de 11. Este valor se obtuvo por medio de extrapolación, por lo que se toma con reservas.

# %% [markdown]
# 12. **Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''salario ~ ausencias''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#              df     sum_sq    mean_sq          F    PR(>F)
# ausencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $0.000033$ es menor a un nivel de significancia $\alpha=0.05$.
#
# En los residuales del anova se puede ver...

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |

# %% [markdown]
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).

# %% [markdown]
# Y : gastos generales
#
# X : unidades
#
# Porque los gastos generales dependen del nivel de unidades o producción

# %%
import pandas as pd
df = pd.DataFrame({
"gasto_general": [191,170,272,155,280,173,234,116,153,178],
"unidades": [40,42,53,35,56,39,48,30,37,40]
})
df
# Out:
#    gasto_general  unidades
# 0            191        40
# 1            170        42
# 2            272        53
# 3            155        35
# 4            280        56
# 5            173        39
# 6            234        48
# 7            116        30
# 8            153        37
# 9            178        40

# %% [markdown]
# 2.-Realice un diagrama de dispersión para estos datos.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
"gasto_general": [191,170,272,155,280,173,234,116,153,178],
"unidades": [40,42,53,35,56,39,48,30,37,40]
})

x = df['unidades']
y = df['gasto_general']

#Configuración gneral del grafico
plt.figure(
    figsize=(6,4),
    dpi=120
)

#Grafico de dispersion
plt.scatter(
    x, y, marker="*",
    edgecolor='pink',
    alpha=0.9,
    s=50,
    label='Gastos Generales'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

#Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05, y=0.05)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?
#
# Sí, porque los datos aportan de manera clara la suposicon de línealidad

# %% [markdown]
# 4.-Calcule el coeficiente de correlación e interprete el resultado.

# %%
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05


r, valor_p = pearsonr(x,y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación de Pearson (r=0.9835) demuestra la existencia de una correlación lineal positiva muy fuerte entre las unidades y los gastos generales. Esto significa que ambas variables se mueven en la misma dirección de forma casi proporcional. Además, dado que el valor p (0.0000) es menor que el nivel de significancia de α=0.05, se acepta (H1)

# %% [markdown]
# 5.-Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
#Coficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.73%

# %% [markdown]
# Debido al nivel alto de correlación, se concluye que ste nivel de ajuste es altamente confiable para realizar predicciones

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant (x)
modelo = sm.OLS (y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# unidades     6.491497
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$
# \hat y = 1.016760+1.737564X
# $$

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6,4),
    dpi=120
)

# Grafico de dispersion
plt.scatter(
    x, y, marker="*",
    edgecolor='pink',
    alpha=0.9,
    s=50,
    label='Gastos Generales'
)

# Linea de regresión
plt.plot(
    x, y_calculada,
    color='blue',
    linewidth=2,
    label='Recta de Regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

#Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05, y=0.05)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend()
plt.show()

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)

# %%
#intervalos de confianza

modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543

# %% [markdown]
# Justificación

# %% [markdown]
# 8.-Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, residuales,      # <--------------------------------------------------------
    marker="s",       # forma: googlear "matplotlib.markers"
    color='pink',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
# Linealidad: Se cumle ya que los puntos están ditribuidos de manera aleatoria por arriba y de bajo de la línea horizontal.
# Normalidad: Se cumple ya que la mayoría de los puntos se concentra cerca de la línea de cero.
# Homoscedasticidad: Se cumple ya que al obevar el ancho de la dispersion de los puntos a lo largo del eje x, los puntos mantienen una dispersion vertical.
# Independencia: Se cumple ya que los residuo no muestran una tendencia secuencial.

# %% [markdown]
# 9.-Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro

# Prueba de Shapiro-Wilk
# H0: Los datos siguen una distribución normal
# H1: Los datos no siguen una distribución normal
# alpha = 0.05
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh: 0.4f}")

if valor_p_sh > 0.05:
    print("Como el valor-p > 0.05, no rechazamos la hipótesis nula. Los residuales parecen seguir una distribución normal.")
else:
    print("Como el valor-p <= 0.05, rechazamos la hipótesis nula. Los residuales no parecen seguir una distribución normal.")
# Out:
# valor-p (Shapiro) =  0.2205
# Como el valor-p > 0.05, no rechazamos la hipótesis nula. Los residuales parecen seguir una distribución normal.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()

# %% [markdown]
# Ambas gráficas aportan evidencia visual suficiente para asumir que los errores del modelo se distribuyen normalmente.

# %% [markdown]
# 10.-Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
from statsmodels.stats.api import het_breuschpagan

# Prueba de Breusch-Pagan
# H0: Hay homoscedasticidad (la varianza de los residuales es constante)
# H1: Hay heteroscedasticidad (la varianza de los residuales no es constante)
# alpha = 0.05

_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f"valor-p (Breusch-Pagan) = {valor_p_bp: 0.4f}")

if valor_p_bp > 0.05:
    print("Como el valor-p > 0.05, no rechazamos la hipótesis nula. Hay homoscedasticidad en los residuales.")
else:
    print("Como el valor-p <= 0.05, rechazamos la hipótesis nula. Hay heteroscedasticidad en los residuales.")
# Out:
# valor-p (Breusch-Pagan) =  0.9858
# Como el valor-p > 0.05, no rechazamos la hipótesis nula. Hay homoscedasticidad en los residuales.

# %% [markdown]
# Se observa que el valor p es notablemente superior, por lo cual se acepta hipótesis alternativas, se concluye que los errores del modelo cumplen con el supuesto de homocedasticidad. La estabilidad del modelo de regresión lineal y valida que la precisión de las predicciones se mantiene uniforme a lo largo de todo el rango de los datos estudiados.

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar
y_25 = modelo.predict([1, 35])
y_32 = modelo.predict([1, 32])

print(f"Para x = 35, y =  {y_25[0]: 0.4f}")
print(f"Para x = 32, y =  {y_32[0]: 0.4f}")
# Out:
# Para x = 35, y =   146.7595
# Para x = 32, y =   127.2850

# %%
df
# Out:
#    gasto_general  unidades
# 0            191        40
# 1            170        42
# 2            272        53
# 3            155        35
# 4            280        56
# 5            173        39
# 6            234        48
# 7            116        30
# 8            153        37
# 9            178        40

# %% [markdown]
# Estos resultados reflejan de manera clara una relación lineal positiva entre ambas variables: a menor volumen de unidades producidas, los gastos generales disminuyen.

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''gasto_general ~ unidades''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# Esto demuestra con una certeza estadística muy alta que la variable "unidades" tiene un efecto real y significativo para predecir los "gastos generales"

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |

# %% [markdown]
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
#
# $Y$: Venta de linea blanca
#
# $X$: Construcción de casas
#
# Porque si se construyan mas casas se venden mas aparatos de línea blanca.

# %%
import pandas as pd
df = pd.DataFrame({
"Venta_línea_blanca": [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0],
"construcción_de_casas": [2.0, 2.5,3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0 ]
})
df
# Out:
#    Venta_línea_blanca  construcción_de_casas
# 0                 5.0                    2.0
# 1                 5.5                    2.5
# 2                 6.0                    3.2
# 3                 7.0                    3.6
# 4                 7.2                    3.7
# 5                 7.7                    4.0
# 6                 8.4                    4.2
# 7                 9.0                    4.6
# 8                 9.7                    4.8
# 9                10.0                    5.0

# %% [markdown]
# 2. Realice un diagrama de dispersión para estos datos.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
"Venta_línea_blanca": [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0],
"construcción_de_casas": [2.0, 2.5,3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0 ]
})

x = df['construcción_de_casas']
y = df['Venta_línea_blanca']

#Configuración gneral del grafico
plt.figure(
    figsize=(6,4),
    dpi=120
)

#Grafico de dispersion
plt.scatter(
    x, y, marker="*",
    edgecolor='pink',
    alpha=0.9,
    s=50,
    label='Gastos Generales'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construcción de casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Venta línea blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

#Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05, y=0.05)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?
#
# Sí, porque los datos aportan de manera clara la suposicon de línealidad

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05


r, valor_p = pearsonr(x,y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9808
# valor_p:  0.0000

# %% [markdown]
# Dado que el valor p es igual a 0.0000 (menor al nivel de significancia estándar α=0.05), se acepta hipótesis alternativa. Esto confirma que la relación lineal es estadísticamente significativa y altamente confiable, descartando que se deba al azar.

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.metrics import r2_score

df = pd.DataFrame({
"Venta_línea_blanca": [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0],
"construcción_de_casas": [2.0, 2.5,3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0 ]
})

x = df['construcción_de_casas']
y = df['Venta_línea_blanca']

x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

#Coficiente de determinación
r2 = r2_score(y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.19%

# %% [markdown]
# El modelo posee un excelente nivel de ajuste, lo que demuestra que la recta de regresión es altamente confiable y una herramienta estadística ideal para realizar pronósticos precisos de ventas en función de la construcción de vivienda.

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant (x)
modelo = sm.OLS (y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                    1.016760
# construcción_de_casas    1.737564
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat y = 1.016760+1.737564X
# $$

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6,4),
    dpi=120
)

# Grafico de dispersion
plt.scatter(
    x, y, marker="*",
    edgecolor='pink',
    alpha=0.9,
    s=50,
    label='Gastos Generales'
)

# Linea de regresión
plt.plot(
    x, y_calculada,
    color='blue',
    linewidth=2,
    label='Recta de Regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construcción de casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Venta de línea blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

#Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05, y=0.05)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend()
plt.show()

# %%
modelo.params
# Out:
# const                    1.016760
# construcción_de_casas    1.737564
# dtype: float64

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)

# %%
#Regresion ajutada ( b1 )

modelo.conf_int(alpha = 0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# construcción_de_casas  1.455693  2.019435

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, residuales,      # <--------------------------------------------------------
    marker="*",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construccón de casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Venta de línea blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
#
# + Linealidad: Se cumple ya que los residuales se encuentran dispersos de manera aleatoria tanto por encima como por debajo del eje cero. No forman curvas, parábolas ni patrones en forma de "U", lo que valida que el modelo lineal es el adecuado.
# + Normalidad: Se cumple ya que la mayoría de los errores se agrupan de forma densa cerca de la línea del cero y la presencia de puntos disminuye a medida que se alejan hacia los extremos de las colas.
# + Homoscedasticidad: Se cumple ya que a lo largo de todo el eje X, la dispersión vertical de los puntos se mantiene en una "banda" de amplitud relativamente constante. No hay un patrón de "embudo" o abanico, lo que significa que la varianza de los errores es constante.
# + Independencia: Se cumple ya que no se detectan tendencias secuenciales, rachas continuas hacia arriba o hacia abajo, ni agrupaciones cíclicas que indiquen que un error afecte al siguiente. Los residuos muestran un comportamiento puramente aleatorio.

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8463507249054649

# %% [markdown]
# Ambas herramientas aportan la evidencia visual suficiente para validar de forma segura el comportamiento normal de los errores en este modelo de regresión.

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
from statsmodels.stats.api import het_breuschpagan

# Prueba de Breusch-Pagan
# H0: Hay homoscedasticidad (la varianza de los residuales es constante)
# H1: Hay heteroscedasticidad (la varianza de los residuales no es constante)
# alpha = 0.05

_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f"valor-p (Breusch-Pagan) = {valor_p_bp: 0.4f}")

if valor_p_bp > 0.05:
    print("Como el valor-p > 0.05, no rechazamos la hipótesis nula. Hay homoscedasticidad en los residuales.")
else:
    print("Como el valor-p <= 0.05, rechazamos la hipótesis nula. Hay heteroscedasticidad en los residuales.")
# Out:
# valor-p (Breusch-Pagan) =  0.1581
# Como el valor-p > 0.05, no rechazamos la hipótesis nula. Hay homoscedasticidad en los residuales.

# %% [markdown]
# Se concluye que el modelo cumple formalmente con el supuesto de homocedasticidad (varianza constante). Esto valida estadísticamente que la precisión y variabilidad de los errores en las predicciones de venta de línea blanca se mantiene uniforme a lo largo de todo el rango de construcción de casas analizado.

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar
y_25 = modelo.predict([1, 35])
y_32 = modelo.predict([1, 32])

print(f"Para x = 35, y =  {y_25[0]: 0.4f}")
print(f"Para x = 32, y =  {y_32[0]: 0.4f}")
# Out:
# Para x = 35, y =   61.8315
# Para x = 32, y =   56.6188

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''Q('Venta_línea_blanca') ~ Q('construcción_de_casas')''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df     sum_sq    mean_sq           F  \
# Q('construcción_de_casas')  1.0  25.976581  25.976581  202.069951
# Residual                    8.0   1.028419   0.128552         NaN
#
#                                   PR(>F)
# Q('construcción_de_casas')  5.841003e-07
# Residual                             NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |

# %%
import pandas as pd
df = pd.DataFrame({
"número_interrupciones_al_trabajador": [5, 10, 10, 15, 15, 20, 20, 25],
"calificación_del_trabajador_en_la_prueba_de_hostilidad": [58, 41, 45, 27, 26, 12, 16, 3 ]
})
df
# Out:
#    número_interrupciones_al_trabajador  \
# 0                                    5
# 1                                   10
# 2                                   10
# 3                                   15
# 4                                   15
# 5                                   20
# 6                                   20
# 7                                   25
#
#    calificación_del_trabajador_en_la_prueba_de_hostilidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %% [markdown]
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
#
# $Y$: Calficación el trabajaor en prubas en hostilidad
#
# $X$: Número  interrupcon al trabajador
#
# Porque mientras mas interrupciones reciba el trabajador, se espera a que camb u calificación de prueba.

# %% [markdown]
# 2. Realice un diagrama de dispersión para estos datos.

# %%
x = df['número_interrupciones_al_trabajador']
y = df['calificación_del_trabajador_en_la_prueba_de_hostilidad']

# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Número interrupciones al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calificación del trabajador en la prueba de hostilidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.show()

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?

# %% [markdown]
# Justificación

# %% [markdown]
# 4. Calcule el coeficiente de correlación e interprete el resultado.

# %%
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05


r, valor_p = pearsonr(x,y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.9928
# valor_p:  0.0000

# %% [markdown]
# Esto confirma de manera concluyente que la relación lineal observada es estadísticamente significativa y altamente confiable, descartando cualquier posibilidad de que el resultado sea producto del azar.

# %% [markdown]
# 5. Calcule el coeficiente de determinación e interprete el resultado

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                                  70.5
# número_interrupciones_al_trabajador    -2.8
# dtype: float64

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

#Coficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  98.58%

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant (x)
modelo = sm.OLS (y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                                  70.5
# número_interrupciones_al_trabajador    -2.8
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat y = 70.5-2.8X
# $$

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6,4),
    dpi=120
)

# Grafico de dispersion
plt.scatter(
    x, y, marker="*",
    edgecolor='Blue',
    alpha=0.9,
    s=50,
    label='Gastos Generales'
)

# Linea de regresión
plt.plot(
    x, y_calculada,
    color='red',
    linewidth=2,
    label='Recta de Regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Numro de interrupcions al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calficación del trbajador', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

#Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05, y=0.05)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend()
plt.show()

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)

# %%
#Regresion ajutada ( b1 )

modelo.conf_int(alpha = 0.05)
# Out:
#                                              0          1
# const                                65.051384  75.948616
# número_interrupciones_al_trabajador  -3.136296  -2.463704

# %% [markdown]
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Recalculamos los residuales para asegurar que coincidan con el modelo actual de Problema 5
residuales = modelo.resid

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, residuales,      # <--------------------------------------------------------
    marker="s",       # forma: googlear "matplotlib.markers"
    color='orange',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    x, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Numero de interrupcions al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calficación del trbajador', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.054816491127669634

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# %%
from statsmodels.stats.api import het_breuschpagan

# Prueba de Breusch-Pagan
# H0: Hay homoscedasticidad (la varianza de los residuales es constante)
# H1: Hay heteroscedasticidad (la varianza de los residuales no es constante)
# alpha = 0.05

_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f"valor-p (Breusch-Pagan) = {valor_p_bp: 0.4f}")

if valor_p_bp > 0.05:
    print("Como el valor-p > 0.05, no rechazamos la hipótesis nula. Hay homoscedasticidad en los residuales.")
else:
    print("Como el valor-p <= 0.05, rechazamos la hipótesis nula. Hay heteroscedasticidad en los residuales.")
# Out:
# valor-p (Breusch-Pagan) =  0.2482
# Como el valor-p > 0.05, no rechazamos la hipótesis nula. Hay homoscedasticidad en los residuales.

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar
y_25 = modelo.predict([1, 35])
y_32 = modelo.predict([1, 32])

print(f"Para x = 35, y =  {y_25[0]: 0.4f}")
print(f"Para x = 32, y =  {y_32[0]: 0.4f}")
# Out:
# Para x = 35, y =  -27.5000
# Para x = 32, y =  -19.1000

# %% [markdown]
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame({
"Venta_línea_blanca": [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0],
"construcción_de_casas": [2.0, 2.5,3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0 ]
})

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''Q('Venta_línea_blanca') ~ Q('construcción_de_casas')''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df     sum_sq    mean_sq           F  \
# Q('construcción_de_casas')  1.0  25.976581  25.976581  202.069951
# Residual                    8.0   1.028419   0.128552         NaN
#
#                                   PR(>F)
# Q('construcción_de_casas')  5.841003e-07
# Residual                             NaN
